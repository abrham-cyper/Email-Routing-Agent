# %% [markdown]
# # 📧 LLM Project: AI Email Routing
# **Student Group**: Abrham Assefa
# **Course**: NLP 2025-26
#
# ## 1. Objective
# Develop three AI agents to route emails to 5 departments:
# 1. Technical Support
# 2. Customer Service
# 3. Billing and Payments
# 4. Sales and Pre-Sales
# 5. General Inquiry

# %% [markdown]
# ## 2. Data Preparation
# Loading data using the required `load_and_prepare_data` function.

# %%
from src.datapreparation import load_and_prepare_data

# Load and verify data
train_ds, val_ds, test_ds, label_list, label2id, id2label = load_and_prepare_data()
print(f"Training samples: {len(train_ds)}")
print(f"Validation samples: {len(val_ds)}")
print(f"Test samples: {len(test_ds)}")

# %% [markdown]
# ## 3. Agent 1: DistilGPT-2 (Zero-Shot Prompting)
# Using a frozen model to guess the department based on a prompt.

# %%
# Running Agent 1 script externally to save memory
import os
os.system('python src/agent1.py')

# %% [markdown]
# ## 4. Agent 2: DistilGPT-2 (LoRA Fine-tuning)
# Fine-tuning the model using Low-Rank Adaptation (LoRA).

# %%
# Running Agent 2 script externally to save memory
import os
os.system('python src/agent2.py')

# %% [markdown]
# ## 5. Agent 3: DistilBERT (Classification)
# Fine-tuning a BERT-based model specifically for text classification.

# %%
# Running Agent 3 script externally to save memory
import os
os.system('python src/agent3.py')

# %% [markdown]
# ## 6. Comparison & Results
# final performance comparison.

# %%
# Running Visualization script
import os
import IPython.display
os.system('python src/visualize.py')
IPython.display.Image(filename='results/comparison_chart.png')
